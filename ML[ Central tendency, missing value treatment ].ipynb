# %%
import pandas as pd

# %%
df = pd.read_csv("D:\credits.csv")

# %%
df
# Out:
#        person_id         id                name                character  \
# 0           3748    tm84618      Robert De Niro            Travis Bickle
# 1          14658    tm84618        Jodie Foster            Iris Steensma
# 2           7064    tm84618       Albert Brooks                      Tom
# 3           3739    tm84618       Harvey Keitel  Matthew 'Sport' Higgins
# 4          48933    tm84618     Cybill Shepherd                    Betsy
# ...          ...        ...                 ...                      ...
# 77796     736339  tm1059008    Adelaida Buscato                María Paz
# 77797     399499  tm1059008  Luz Stella Luengas             Karen Bayona
# 77798     373198  tm1059008         Inés Prieto                    Fanny
# 77799     378132  tm1059008        Isabel Gaona                   Cacica
# 77800    1950416  tm1059008      Julian Gaviria                      NaN
#
#            role
# 0         ACTOR
# 1         ACTOR
# 2         ACTOR
# 3         ACTOR
# ...

# %%
df.describe()
# Out:
#           person_id
# count  7.780100e+04
# mean   5.294888e+05
# std    6.430167e+05
# min    7.000000e+00
# 25%    4.530600e+04
# 50%    1.983580e+05
# 75%    8.880960e+05
# max    2.462818e+06

# %%
df1 = pd.read_csv("D:\Python 34\ML\DS_data_for_Analysis[002] (1).csv")

# %%
df1
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  24/02/2020          1.0        1.0
# 1          AFG      Asia  Afghanistan  25/02/2020          1.0        0.0
# 2          AFG      Asia  Afghanistan  26/02/2020          1.0        0.0
# 3          AFG      Asia  Afghanistan  27/02/2020          1.0        0.0
# 4          AFG      Asia  Afghanistan  28/02/2020          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 94862      ZWE    Africa     Zimbabwe  06/06/2021      39189.0       21.0
# 94863      ZWE    Africa     Zimbabwe  07/06/2021      39238.0       49.0
# 94864      ZWE    Africa     Zimbabwe  08/06/2021      39321.0       83.0
# 94865      ZWE    Africa     Zimbabwe  09/06/2021      39432.0      111.0
# 94866      ZWE    Africa     Zimbabwe  10/06/2021      39496.0       64.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
df1.isnull().sum()
# Out:
# iso_code                                     0
# continent                                 4480
# location                                     0
# date                                         0
# total_cases                               3107
# new_cases                                 3110
# new_cases_smoothed                        4120
# total_deaths                             13086
# new_deaths                               12930
# new_deaths_smoothed                       4120
# total_cases_per_million                   3597
# new_cases_per_million                     3600
# new_cases_smoothed_per_million            4605
# total_deaths_per_million                 13563
# new_deaths_per_million                   13407
# new_deaths_smoothed_per_million           4605
# reproduction_rate                        18556
# icu_patients                             85346
# icu_patients_per_million                 85346
# hosp_patients                            83050
# ...

# %%
df1.shape
# Out:
# (94867, 60)

# %%
df1.isnull().sum()*100/len(df1)
# Out:
# iso_code                                  0.000000
# continent                                 4.722401
# location                                  0.000000
# date                                      0.000000
# total_cases                               3.275111
# new_cases                                 3.278274
# new_cases_smoothed                        4.342922
# total_deaths                             13.794049
# new_deaths                               13.629608
# new_deaths_smoothed                       4.342922
# total_cases_per_million                   3.791624
# new_cases_per_million                     3.794786
# new_cases_smoothed_per_million            4.854164
# total_deaths_per_million                 14.296858
# new_deaths_per_million                   14.132417
# new_deaths_smoothed_per_million           4.854164
# reproduction_rate                        19.560016
# icu_patients                             89.963844
# ...

# %%
df1['new_deaths']
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 94862    1.0
# 94863    5.0
# 94864    6.0
# 94865    5.0
# 94866    4.0
# Name: new_deaths, Length: 94867, dtype: float64

# %%
df1['hospital_beds_per_thousand']
# Out:
# 0        0.5
# 1        0.5
# 2        0.5
# 3        0.5
# 4        0.5
#         ...
# 94862    1.7
# 94863    1.7
# 94864    1.7
# 94865    1.7
# 94866    1.7
# Name: hospital_beds_per_thousand, Length: 94867, dtype: float64

# %%
df1['new_deaths_o'] = df1['new_deaths'].fillna(0)

# %%
df1['new_deaths'].unique()
# Out:
# array([       nan, 1.0000e+00, 0.0000e+00, ..., 1.0410e+04, 1.0420e+04,
#        1.5548e+04])

# %%
df1.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  9.176000e+04   91757.000000        90747.000000  8.178100e+04
# mean   9.823545e+05    6059.404253         6086.950436  2.703805e+04
# std    6.765660e+06   38082.374634        37832.857208  1.610378e+05
# min    1.000000e+00  -74347.000000        -6223.000000  1.000000e+00
# 25%    1.148000e+03       2.000000            7.286000  5.100000e+01
# 50%    1.257150e+04      72.000000           90.143000  3.520000e+02
# 75%    1.323872e+05     797.000000          835.714000  3.454000e+03
# max    1.748673e+08  906008.000000       826389.571000  3.773339e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  81937.000000         90747.000000             91270.000000
# mean     147.089288           131.678010             12072.139046
# std      804.364326           743.874762             22560.724598
# min    -1918.000000          -232.143000                 0.001000
# ...

# %%
# min     25%      50%       75%       max

# -1918   0         2        18        18051

# data is right side skewed

# %%
df2 = pd.read_csv("D:\Python 34\ML\ML[pandas]\Bengaluru_House_Data.csv")

# %%
df2
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df2.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
df2.describe()
# Out:
#                bath       balcony         price
# count  13247.000000  12711.000000  13320.000000
# mean       2.692610      1.584376    112.565627
# std        1.341458      0.817263    148.971674
# min        1.000000      0.000000      8.000000
# 25%        2.000000      1.000000     50.000000
# 50%        2.000000      2.000000     72.000000
# 75%        3.000000      2.000000    120.000000
# max       40.000000      3.000000   3600.000000

# %%
import seaborn as sns

# %%
sns.pairplot(data=df2)

# %%
sns.histplot(x='balcony',data =df2,kde=True,binwidth=5)
# Out:
# <AxesSubplot:xlabel='balcony', ylabel='Count'>

# %% [markdown]
# ### give mean as a feature to dataset
# #### df1['new_deaths_N'] = df1['new_deaths'].fillna(df1['new_deaths'].mean())

# %%
df1['new_deaths_N'] = df1['new_deaths'].fillna(df1['new_deaths'].mean())

# %%
df1
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  24/02/2020          1.0        1.0
# 1          AFG      Asia  Afghanistan  25/02/2020          1.0        0.0
# 2          AFG      Asia  Afghanistan  26/02/2020          1.0        0.0
# 3          AFG      Asia  Afghanistan  27/02/2020          1.0        0.0
# 4          AFG      Asia  Afghanistan  28/02/2020          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 94862      ZWE    Africa     Zimbabwe  06/06/2021      39189.0       21.0
# 94863      ZWE    Africa     Zimbabwe  07/06/2021      39238.0       49.0
# 94864      ZWE    Africa     Zimbabwe  08/06/2021      39321.0       83.0
# 94865      ZWE    Africa     Zimbabwe  09/06/2021      39432.0      111.0
# 94866      ZWE    Africa     Zimbabwe  10/06/2021      39496.0       64.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %% [markdown]
# ### give Median as a feature to dataset
# #### df1['new_deaths_Median'] = df1['new_deaths'].fillna(df1['new_deaths'].median())

# %%
df1['new_deaths_Median'] = df1['new_deaths'].fillna(df1['new_deaths'].median())

# %%
df1
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  24/02/2020          1.0        1.0
# 1          AFG      Asia  Afghanistan  25/02/2020          1.0        0.0
# 2          AFG      Asia  Afghanistan  26/02/2020          1.0        0.0
# 3          AFG      Asia  Afghanistan  27/02/2020          1.0        0.0
# 4          AFG      Asia  Afghanistan  28/02/2020          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 94862      ZWE    Africa     Zimbabwe  06/06/2021      39189.0       21.0
# 94863      ZWE    Africa     Zimbabwe  07/06/2021      39238.0       49.0
# 94864      ZWE    Africa     Zimbabwe  08/06/2021      39321.0       83.0
# 94865      ZWE    Africa     Zimbabwe  09/06/2021      39432.0      111.0
# 94866      ZWE    Africa     Zimbabwe  10/06/2021      39496.0       64.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %% [markdown]
# ### give Mode as a feature to dataset
# #### df1['continent_Mode'] = df1['continent'].fillna(df1['continent'][0])

# %%
df1['continent'].mode()
# Out:
# 0    Africa
# Name: continent, dtype: object

# %%
df1['continent'].mode()[0]
# Out:
# 'Africa'

# %%
df1['continent_Mode'] = df1['continent'].fillna(df1['continent'][0])

# %%
df1
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  24/02/2020          1.0        1.0
# 1          AFG      Asia  Afghanistan  25/02/2020          1.0        0.0
# 2          AFG      Asia  Afghanistan  26/02/2020          1.0        0.0
# 3          AFG      Asia  Afghanistan  27/02/2020          1.0        0.0
# 4          AFG      Asia  Afghanistan  28/02/2020          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 94862      ZWE    Africa     Zimbabwe  06/06/2021      39189.0       21.0
# 94863      ZWE    Africa     Zimbabwe  07/06/2021      39238.0       49.0
# 94864      ZWE    Africa     Zimbabwe  08/06/2021      39321.0       83.0
# 94865      ZWE    Africa     Zimbabwe  09/06/2021      39432.0      111.0
# 94866      ZWE    Africa     Zimbabwe  10/06/2021      39496.0       64.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
df1.isnull().sum()
# Out:
# iso_code                 0
# continent             4480
# location                 0
# date                     0
# total_cases           3107
#                      ...
# excess_mortality     91523
# new_deaths_o             0
# new_deaths_N             0
# new_deaths_Median        0
# continent_Mode           0
# Length: 64, dtype: int64
