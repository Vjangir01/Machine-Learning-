# %%
import pandas as pd

# %%
df = pd.read_csv("D:\Python 34\ML\Churn_Modelling.csv")

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
q1  = df.Age.quantile(0.25)

# %%
q1
# Out:
# 32.0

# %%
q3 = df.Age.quantile(0.75)

# %%
q3
# Out:
# 44.0

# %%
IQR =q3-q1
IQR
# Out:
# 12.0

# %%
lower_bound = q1-(1.5*IQR)
lower_bound
# Out:
# 14.0

# %%
upper_bound = q3+(1.5*IQR)
upper_bound
# Out:
# 62.0

# %%
df1 = df[(df['Age']>=lower_bound) & (df['Age']<=upper_bound)]
df1
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
# outliers find out

# %%
Outlier_df = df[~((df['Age']>lower_bound) & (df['Age']<upper_bound))]

# %%
Outlier_df
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 58           59    15623944        T'ien          511     Spain  Female   66
# 85           86    15805254      Ndukaku          652     Spain  Female   75
# 104         105    15804919     Dunbabin          670     Spain  Female   65
# 158         159    15589975      Maclean          646    France  Female   73
# 181         182    15789669         Hsia          510    France    Male   65
# ...         ...         ...          ...          ...       ...     ...  ...
# 9765       9766    15777067       Thomas          445    France    Male   64
# 9832       9833    15814690  Chukwujekwu          595   Germany  Female   64
# 9879       9880    15669414       Pisano          486   Germany    Male   62
# 9894       9895    15704795        Vagin          521    France  Female   77
# 9936       9937    15653037        Parks          609    France    Male   77
#
# ...

# %%
df1['Age'].value_counts()
# Out:
# 37    478
# 38    477
# 35    474
# 36    456
# 34    447
# 33    442
# 40    432
# 39    423
# 32    418
# 31    404
# 41    366
# 29    348
# 30    327
# 42    321
# 43    297
# 28    273
# 44    257
# 45    229
# 46    226
# 27    209
# 26    200
# 47    175
# 48    168
# 25    154
# 49    147
# 50    134
# 24    132
# 51    119
# 52    102
# 23     99
# 22     84
# 54     84
# 55     82
# 57     75
# 53     74
# 56     70
# 58     67
# 60     62
# 59     62
# 61     53
# 21     53
# 62     52
# 20     40
# 19     27
# 18     22
# Name: Age, dtype: int64

# %%
df1['Age'].mean()
# Out:
# 37.79172285032673

# %%
df1['Age'].mode()
# Out:
# 0    37
# Name: Age, dtype: int64

# %%
df1['Age'].median()
# Out:
# 37.0

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df['zscore'] = (df['Age'] - df['Age'].mean())/df.Age.std()

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df[((df['zscore'] > -3) & (df['zscore'] < +3))]
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df[~((df['zscore'] > -3) & (df['zscore'] < +3))]
# Out:
#       RowNumber  CustomerId     Surname  CreditScore Geography  Gender  Age  \
# 85           86    15805254     Ndukaku          652     Spain  Female   75
# 158         159    15589975     Maclean          646    France  Female   73
# 230         231    15808473    Ringrose          673    France    Male   72
# 252         253    15793726   Matveyeva          681    France  Female   79
# 310         311    15712287  Pokrovskii          652    France  Female   80
# ...         ...         ...         ...          ...       ...     ...  ...
# 9646       9647    15603111        Muir          850     Spain    Male   71
# 9671       9672    15636061        Pope          649   Germany    Male   78
# 9736       9737    15644103       Wells          659     Spain    Male   78
# 9894       9895    15704795       Vagin          521    France  Female   77
# 9936       9937    15653037       Parks          609    France    Male   77
#
# ...

# %%
df[~((df['zscore'] > -2) & (df['zscore'] < +2))]
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 42           43    15687946      Osborne          556    France  Female   61
# 44           45    15684171      Bianchi          660     Spain  Female   61
# 58           59    15623944        T'ien          511     Spain  Female   66
# 85           86    15805254      Ndukaku          652     Spain  Female   75
# 104         105    15804919     Dunbabin          670     Spain  Female   65
# ...         ...         ...          ...          ...       ...     ...  ...
# 9832       9833    15814690  Chukwujekwu          595   Germany  Female   64
# 9879       9880    15669414       Pisano          486   Germany    Male   62
# 9894       9895    15704795        Vagin          521    France  Female   77
# 9897       9898    15810563           Ho          678     Spain  Female   61
# 9936       9937    15653037        Parks          609    France    Male   77
#
# ...

# %%
 df[~((df['zscore'] > -1) & (df['zscore'] < +1))]
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 6             7    15592531     Bartlett          822    France    Male   50
# 9            10    15592389           H?          684    France    Male   27
# 11           12    15737173      Andrews          497     Spain    Male   24
# 13           14    15691483         Chin          549    France  Female   25
# 16           17    15737452        Romeo          653   Germany    Male   58
# ...         ...         ...          ...          ...       ...     ...  ...
# 9979       9980    15692664       Diribe          677    France  Female   58
# 9989       9990    15605622     McMillan          841     Spain    Male   28
# 9991       9992    15769959  Ajuluchukwu          597    France  Female   53
# 9993       9994    15569266       Rahman          644    France    Male   28
# 9999      10000    15628319       Walker          792    France  Female   28
#
# ...

# %%
df22 = df[((df['zscore'] > -1) & (df['zscore'] < +1))]

# %%
import pandas as pd

# %%
import numpy

# %%
print(df['Age'].quantile(0.25)) 
print(df['Age'].quantile(0.75)) 
df['Age'] = np.where(df['Age'] > 42, 32, df['Age'])
df.describe()
# Out:
# 32.0
# 42.0
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     33.404900      5.012800
# std     2886.89568  7.193619e+04     96.653299      4.690603      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     32.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     37.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     42.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
df['Age'].count()
# Out:
# 10000
